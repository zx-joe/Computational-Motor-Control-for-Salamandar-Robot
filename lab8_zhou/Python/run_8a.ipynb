# %% [markdown]
# # drive increase linearly from 0 to 6 within 30 seconds

# %%
# %run run_network.py
# Out:
# [PYLOG-24840] 2020-05-31 09:58:44,263 - [INFO] - run_network.py::87::run_network():
# Time to run simulation for 3000 steps: 28.73014783859253 [s]
# -
# [PYLOG-24840] 2020-05-31 09:58:44,263 - [WARNING] - run_network.py::91::run_network():
# Implement plots of 8a
# -

# %% [markdown]
# # drive=0.5

# %%
# %run run_network.py
# Out:
# [PYLOG-14312] 2020-05-31 09:46:44,277 - [INFO] - run_network.py::86::run_network():
# Time to run simulation for 1000 steps: 9.534360885620117 [s]
# -
# [PYLOG-14312] 2020-05-31 09:46:44,293 - [WARNING] - run_network.py::90::run_network():
# Implement plots of 8a
# -

# %% [markdown]
# # walking: drive=1.5

# %%
# %run run_network.py
# Out:
# [PYLOG-13516] 2020-05-28 10:52:34,287 - [INFO] - run_network.py::86::run_network():
# Time to run simulation for 1000 steps: 10.025307655334473 [s]
# -
# [PYLOG-13516] 2020-05-28 10:52:34,288 - [WARNING] - run_network.py::90::run_network():
# Implement plots of 8a
# -

# %% [markdown]
# # walking: drive=2

# %%
# %run run_network.py
# Out:
# [PYLOG-15184] 2020-05-15 17:33:19,279 - [INFO] - run_network.py::86::run_network():
# Time to run simulation for 1000 steps: 9.998501777648926 [s]
# -
# [PYLOG-15184] 2020-05-15 17:33:19,279 - [WARNING] - run_network.py::90::run_network():
# Implement plots of 8a
# -

# %% [markdown]
# # walking: drive=2.5

# %%
# %run run_network.py
# Out:
# [PYLOG-3596] 2020-05-28 10:53:21,810 - [INFO] - run_network.py::86::run_network():
# Time to run simulation for 1000 steps: 9.964724779129028 [s]
# -
# [PYLOG-3596] 2020-05-28 10:53:21,810 - [WARNING] - run_network.py::90::run_network():
# Implement plots of 8a
# -

# %% [markdown]
# # swimming: drive=3.5

# %%
# %run run_network.py
# Out:
# [PYLOG-5240] 2020-05-28 10:54:24,850 - [INFO] - run_network.py::86::run_network():
# Time to run simulation for 1000 steps: 10.089465618133545 [s]
# -
# [PYLOG-5240] 2020-05-28 10:54:24,850 - [WARNING] - run_network.py::90::run_network():
# Implement plots of 8a
# -

# %% [markdown]
# # swimming: drive=4

# %%
# %run run_network.py
# Out:
# [PYLOG-17264] 2020-05-15 17:34:55,167 - [INFO] - run_network.py::86::run_network():
# Time to run simulation for 1000 steps: 10.099439144134521 [s]
# -
# [PYLOG-17264] 2020-05-15 17:34:55,170 - [WARNING] - run_network.py::90::run_network():
# Implement plots of 8a
# -

# %% [markdown]
# # swimming: drive=4.5

# %%
# %run run_network.py
# Out:
# [PYLOG-16600] 2020-05-28 10:54:58,913 - [INFO] - run_network.py::86::run_network():
# Time to run simulation for 1000 steps: 10.285293102264404 [s]
# -
# [PYLOG-16600] 2020-05-28 10:54:58,913 - [WARNING] - run_network.py::90::run_network():
# Implement plots of 8a
# -

# %% [markdown]
# # drive=5.5

# %%
# %run run_network.py
# Out:
# [PYLOG-5060] 2020-05-31 09:47:52,010 - [INFO] - run_network.py::86::run_network():
# Time to run simulation for 1000 steps: 10.317116022109985 [s]
# -
# [PYLOG-5060] 2020-05-31 09:47:52,010 - [WARNING] - run_network.py::90::run_network():
# Implement plots of 8a
# -
