# %%
# %run lab6.py
# Out:
# [PYLOG-3800] 2020-04-18 22:20:21,100 - [INFO] - lab6.py::9::main():
# Implementing Lab 6 : Exercise 2
# -
# [PYLOG-3800] 2020-04-18 22:20:21,100 - [INFO] - exercise2.py::170::exercise2():
# 2a
# -
# [PYLOG-3800] 2020-04-18 22:20:21,392 - [INFO] - exercise2.py::221::exercise2():
# 2b
# -
# [PYLOG-3800] 2020-04-18 22:20:21,392 - [INFO] - system_parameters.py::133::g():
# Changed gravity to 9.81 [N-m/s2]
# -
# [PYLOG-3800] 2020-04-18 22:20:21,392 - [DEBUG] - system_parameters.py::151::m():
# Changed pendulum mass to 0.25 [kg]
# -
# [PYLOG-3800] 2020-04-18 22:20:21,392 - [DEBUG] - system_parameters.py::178::L():
# Changed pendulum length to 1.0 [m]
# -
# [PYLOG-3800] 2020-04-18 22:20:21,392 - [INFO] - system_parameters.py::118::__init__():
# ...
# -
# [PYLOG-3800] 2020-04-18 22:20:21,392 - [DEBUG] - system_parameters.py::178::L():
# Changed pendulum length to 1.0 [m]
# -
# [PYLOG-3800] 2020-04-18 22:20:21,392 - [DEBUG] - system_parameters.py::151::m():
# Changed pendulum mass to 0.25 [kg]
# -
# ...
