# %%
# %run lab6.py
# Out:
# [PYLOG-9408] 2020-04-22 15:58:52,959 - [INFO] - system_parameters.py::133::g():
# Changed gravity to 9.81 [N-m/s2]
# -
# [PYLOG-9408] 2020-04-22 15:58:52,962 - [DEBUG] - system_parameters.py::151::m():
# Changed pendulum mass to 0.25 [kg]
# -
# [PYLOG-9408] 2020-04-22 15:58:52,962 - [DEBUG] - system_parameters.py::178::L():
# Changed pendulum length to 1.0 [m]
# -
# [PYLOG-9408] 2020-04-22 15:58:52,963 - [INFO] - system_parameters.py::118::__init__():
# ...
# -
# [PYLOG-9408] 2020-04-22 15:58:53,007 - [INFO] - lab6.py::9::main():
# Implementing Lab 6 : Exercise 2
# -
# [PYLOG-9408] 2020-04-22 15:58:53,008 - [INFO] - exercise2.py::170::exercise2():
# 2a
# -
# [PYLOG-9408] 2020-04-22 15:58:53,348 - [INFO] - exercise2.py::221::exercise2():
# 2b
# -
# [PYLOG-9408] 2020-04-22 15:58:53,348 - [INFO] - system_parameters.py::133::g():
# Changed gravity to 9.81 [N-m/s2]
# -
# [PYLOG-9408] 2020-04-22 15:58:53,348 - [DEBUG] - system_parameters.py::151::m():
# Changed pendulum mass to 0.25 [kg]
# -
# ...
