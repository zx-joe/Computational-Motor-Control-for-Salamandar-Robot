# %%
# %run lab5.py
# Out:
# [PYLOG-17840] 2020-04-22 17:21:52,055 - [INFO] - lab5.py::8::main():
# Implementing Lab 5 : Exercise 1
# -
# [PYLOG-17840] 2020-04-22 17:21:52,055 - [WARNING] - exercise1.py::39::exercise1a():
# Loading default muscle parameters
# -
# [PYLOG-17840] 2020-04-22 17:21:52,055 - [INFO] - exercise1.py::40::exercise1a():
# Muscle parameters :
#     l_slack : 0.13 [m]
#     l_opt : 0.11 [m]
#     f_max : 1500 [N]
#     v_max : -12 [m/s]
#     pennation : 1 []
#
# -
# [PYLOG-17840] 2020-04-22 17:21:52,055 - [INFO] - exercise1.py::41::exercise1a():
# Use the parameters object to change the muscle parameters
# -
# [PYLOG-17840] 2020-04-22 17:21:52,055 - [WARNING] - exercise1.py::46::exercise1a():
# Isometric muscle contraction to be completed
# -
# [PYLOG-17840] 2020-04-22 17:21:52,063 - [INFO] - isometric_muscle_system.py::61::add_muscle():
# Added new muscle model to the system
# -
# [PYLOG-17840] 2020-04-22 17:21:52,063 - [INFO] - isometric_muscle_system.py::147::integrate():
# ...
