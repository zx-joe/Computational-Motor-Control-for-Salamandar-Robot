# %%
# %run test_sr2.py
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████| 30000/30000 [00:29<00:00, 1000.30it/s]
# Total simulation time: 29.99255919456482 [s]

# %%
# %run run_network.py
# Out:
# [PYLOG-21100] 2020-05-07 22:38:22,301 - [WARNING] - robot_parameters.py::43::set_frequencies():
# Coupling weights must be set
# -
# [PYLOG-21100] 2020-05-07 22:38:22,303 - [WARNING] - robot_parameters.py::47::set_coupling_weights():
# Coupling weights must be set
# -
# [PYLOG-21100] 2020-05-07 22:38:22,304 - [WARNING] - robot_parameters.py::51::set_phase_bias():
# Phase bias must be set
# -
# [PYLOG-21100] 2020-05-07 22:38:22,305 - [WARNING] - robot_parameters.py::55::set_amplitudes_rate():
# Convergence rates must be set
# -
# [PYLOG-21100] 2020-05-07 22:38:22,305 - [WARNING] - robot_parameters.py::59::set_nominal_amplitudes():
# Nominal amplitudes must be set
# -
# [PYLOG-21100] 2020-05-07 22:38:31,532 - [INFO] - run_network.py::86::run_network():
# Time to run simulation for 1000 steps: 9.224528312683105 [s]
# -
# [PYLOG-21100] 2020-05-07 22:38:31,533 - [WARNING] - run_network.py::90::run_network():
# Implement plots
# -
# No handles with labels found to put in legend.
